# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_62888\4080736814.py in <module>
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing()

# %%
housing.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'feature_names', 'DESCR'])

# %%
dataset=pd.DataFrame(housing.data,columns=housing.feature_names)

# %%
dataset
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
dataset2=pd.DataFrame(housing.target,columns=housing.target_names)
dataset2
# Out:
#        MedHouseVal
# 0            4.526
# 1            3.585
# 2            3.521
# 3            3.413
# 4            3.422
# ...            ...
# 20635        0.781
# 20636        0.771
# 20637        0.923
# 20638        0.847
# 20639        0.894
#
# [20640 rows x 1 columns]

# %%
#combined table using a test code 
# Concatenate along columns (axis=1)
data = pd.concat([dataset, dataset2], axis=1)
data
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
data.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
data["MedHouseVal"].value_counts()
# Out:
# MedHouseVal
# 5.00001    965
# 1.37500    122
# 1.62500    117
# 1.12500    103
# 1.87500     93
#           ...
# 3.59200      1
# 0.54900      1
# 3.77600      1
# 0.81200      1
# 0.47000      1
# Name: count, Length: 3842, dtype: int64

# %%
# print the correlation between variables to identify relationship between them

# %%
data.corr()
# Out:
#                MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc       1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge    -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms     0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms   -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population   0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup     0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude    -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude   -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# MedHouseVal  0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#              Latitude  Longitude  MedHouseVal
# MedInc      -0.079809  -0.015176     0.688075
# HouseAge     0.011173  -0.108197     0.105623
# AveRooms     0.106389  -0.027540     0.151948
# ...

# %% [markdown]
# this dataset is prebuild, so things like null values is not present , that is quite good <br> for confirmation we can check

# %%
data.isna().sum()
# Out:
# MedInc         0
# HouseAge       0
# AveRooms       0
# AveBedrms      0
# Population     0
# AveOccup       0
# Latitude       0
# Longitude      0
# MedHouseVal    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
#Faire des analyses approfondies sur les colonnes , à voir .......................
import seaborn as sns
sns.pairplot(dataset)

# %%
plt.figure(figsize=(8, 5))  # Set the figure size

# Scatter plot for MedInc vs. MedHouseVal
plt.scatter(data['MedInc'], data['MedHouseVal'], alpha=0.5, edgecolors='black', s=15)  # alpha for transparency, s for size

# Add labels and title
plt.xlabel("Median Income (in $10,000s)", fontsize=14)  # More descriptive x-axis label
plt.ylabel("Median House Value (in $100,000s)", fontsize=14)  # More descriptive y-axis label
plt.title("Relationship between Median Income and Median House Value", fontsize=16)
# Out:
# Text(0.5, 1.0, 'Relationship between Median Income and Median House Value')

# %%
# this value correlated a litte bit with the dependant variable / let's try this one

# %%
plt.figure(figsize=(6, 2))  # Set the figure size

# Scatter plot for MedInc vs. MedHouseVal
plt.scatter(data['AveBedrms'], data['AveRooms'], alpha=0.5, edgecolors='w', s=30)  # alpha for transparency, s for size

# Add labels and title
plt.xlabel("rooms", fontsize=14)  # More descriptive x-axis label
plt.ylabel("bed rooms", fontsize=14)  # More descriptive y-axis label
plt.title("Relationship between rooms and bed rooms", fontsize=16)
# Out:
# Text(0.5, 1.0, 'Relationship between rooms and bed rooms')

# %%
plt.figure(figsize=(6, 3))  # Set the figure size

# Scatter plot for MedInc vs. MedHouseVal
plt.scatter(data['HouseAge'], data['MedHouseVal'], alpha=0.5, edgecolors='yellow', s=15)  # alpha for transparency, s for size

# Add labels and title
plt.xlabel("House Age", fontsize=14)  # More descriptive x-axis label
plt.ylabel("Median House Value", fontsize=14)  # More descriptive y-axis label
plt.title("Relationship between Median Income and Median House Value", fontsize=16)
# Out:
# Text(0.5, 1.0, 'Relationship between Median Income and Median House Value')

# %%
plt.figure(figsize=(6, 4))  # Set the figure size

# Scatter plot for MedInc vs. MedHouseVal
plt.scatter(data['Population'], data['MedHouseVal'], alpha=0.5, edgecolors='orange', s=15)  # alpha for transparency, s for size

# Add labels and title
plt.xlabel("Population", fontsize=14)  # More descriptive x-axis label
plt.ylabel("Median House Value", fontsize=14)  # More descriptive y-axis label
plt.title("Relationship between Population and Median House Value", fontsize=16)
# Out:
# Text(0.5, 1.0, 'Relationship between Population and Median House Value')

# %%
sns.regplot(x="MedInc", y="MedHouseVal", data=data, scatter_kws={'alpha':0.5, 's':15, 'color':'black'}, line_kws={'color':'green','alpha':0.5})

# Add labels and title
plt.xlabel("Median Income (in $10,000s)", fontsize=16)  # More descriptive x-axis label
plt.ylabel("Median House Value (in $100,000s)", fontsize=16)  # More descriptive y-axis label
plt.title("Relationship between Median Income and Median House Value", fontsize=16)

# Add grid for better readability
plt.grid(True, linestyle='--', alpha=0.8)

# Show the plot
plt.show()

# %%
sns.regplot(x="Population", y="MedHouseVal", data=data, scatter_kws={'alpha':0.5, 's':15, 'color':'grey'}, line_kws={'color':'green','alpha':0.5})

# Add labels and title
plt.xlabel("", fontsize=16)  # More descriptive x-axis label
plt.ylabel("", fontsize=16)  # More descriptive y-axis label
plt.title("Relationship between variable", fontsize=16)

# Add grid for better readability
plt.grid(True, linestyle='--', alpha=0.8)

# Show the plot
plt.show()

# %%
X_testing=dataset.iloc[:,:-1]
y_testing=dataset.iloc[:,-1]

# %%
y_testing
# Out:
# 0       -122.23
# 1       -122.22
# 2       -122.24
# 3       -122.25
# 4       -122.25
#           ...
# 20635   -121.09
# 20636   -121.21
# 20637   -121.22
# 20638   -121.32
# 20639   -121.24
# Name: Longitude, Length: 20640, dtype: float64

# %%
X=data.iloc[:,:-1]
y=data.iloc[:,-1]

# %%
print(X)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
print(y)
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: MedHouseVal, Length: 20640, dtype: float64

# %%
#splitting the dataset
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.15, random_state=0)

# %%
#scaling the dataset for feature process since we are in the case of Linear REGRESSION, also to avoid biased result

from sklearn.preprocessing import StandardScaler 
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-0.17948813,  0.42686237,  0.20965786, ..., -0.02504036,
#          1.10748233, -1.11193429],
#        [-0.44739869, -1.32150039, -0.28994749, ...,  0.04024501,
#         -1.4276475 ,  1.2367731 ],
#        [-0.79039782, -0.2089059 ,  0.41401314, ...,  0.06660229,
#          0.94377468, -1.27150677],
#        ...,
#        [-0.3577972 ,  0.18844927, -0.71274217, ..., -0.19712159,
#          0.44329702, -1.16180069],
#        [ 0.92196868,  0.42686237, -0.35576551, ..., -0.12409596,
#         -0.94120192,  0.81789535],
#        [-1.3092872 , -1.08308729, -0.59830792, ...,  0.06600108,
#         -1.32474555,  1.99972901]])

# %%
X_test
# Out:
# array([[ 1.43897524e-01, -5.26790043e-01,  8.97620444e-02, ...,
#          1.85070057e-01, -1.42764750e+00,  1.25671966e+00],
#        [ 9.99844149e-01,  2.67920304e-01,  2.66053397e-01, ...,
#         -4.25734024e-04, -8.00881082e-01,  7.97948792e-01],
#        [ 2.47433518e-01,  2.95072002e-02,  1.95992053e-01, ...,
#         -1.81603419e-02,  1.41151081e+00, -1.13188085e+00],
#        ...,
#        [ 1.13666520e+00, -7.65203147e-01,  4.84676445e-01, ...,
#          5.50650290e-02, -5.57658295e-01,  5.18696957e-01],
#        [-7.87137673e-01, -6.06261078e-01, -6.79489129e-01, ...,
#         -2.09334575e-01, -8.19590527e-01,  6.28403035e-01],
#        [-9.09761308e-01,  1.38051479e+00, -4.61646556e-01, ...,
#          1.83950495e-01, -7.63462192e-01,  6.48349595e-01]])

# %%
import pickle
pickle.dump(scaler,open('scaling.pkl','wb'))

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression(
)

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(lr.intercept_)
print(lr.coef_)
# Out:
# 2.07065003020976
# [ 0.82681809  0.12000705 -0.25388181  0.29548595 -0.00575714 -0.03151764
#  -0.89300314 -0.86230763]

# %%
lr.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
#let's predict it 
reg_pred=lr.predict(X_test)

# %%
reg_pred
# Out:
# array([2.27558853, 2.78692254, 1.90169087, ..., 2.79602784, 1.70687273,
#        1.68633463])

# %%
plt.figure(figsize=(9, 4))  # Set the figure size

# Scatter plot for MedInc vs. MedHouseVal
plt.scatter(y_test, reg_pred, alpha=0.5, edgecolors='red', s=30)  # alpha for transparency, s for size

# Add labels and title
plt.xlabel("rooms", fontsize=14)  # More descriptive x-axis label
plt.ylabel("bed rooms", fontsize=14)  # More descriptive y-axis label
plt.title("Relationship between rooms and bed rooms", fontsize=16)
# Out:
# Text(0.5, 1.0, 'Relationship between rooms and bed rooms')

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

print(mean_absolute_error(y_test,reg_pred))
print(mean_squared_error(y_test,reg_pred))
print(np.sqrt(mean_squared_error(y_test,reg_pred)))
# Out:
# 0.5352682162774167
# 0.536548325607481
# 0.7324945908383768

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,reg_pred)
print(score)
# Out:
# 0.5950581378977451

# %%
#try better model , random Forest
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict(X_test)

# Evaluate performance
#rf_score = rf_model.score(X_test, y_pred_rf)
#print(f"Random Forest R^2 Score: {rf_score}")
# Out:
# Random Forest R^2 Score: 1.0

# %%
plt.figure(figsize=(9, 4))  # Set the figure size

# Scatter plot for MedInc vs. MedHouseVal
plt.scatter(y_test, y_pred_rf, alpha=0.5, edgecolors='yellow', s=30)  # alpha for transparency, s for size

# Add labels and title
plt.xlabel("rooms", fontsize=14)  # More descriptive x-axis label
plt.ylabel("bed rooms", fontsize=14)  # More descriptive y-axis label
plt.title("Relationship between rooms and bed rooms", fontsize=10)
# Out:
# Text(0.5, 1.0, 'Relationship between rooms and bed rooms')

# %%
import numpy as np
print(mean_absolute_error(y_test,y_pred_rf))
print(mean_squared_error(y_test,y_pred_rf))
print(np.sqrt(mean_squared_error(y_test,y_pred_rf)))
# Out:
# 0.32948220968992264
# 0.2615115022765831
# 0.5113819534130855

# %%
score=r2_score(y_test,y_pred_rf)
print(score)
# Out:
# 0.802632960277826

# %%
np.sqrt(mean_squared_error(y_test,y_pred_rf))
# Out:
# 0.5113819534130855

# %%
mean_squared_error(y_test,y_pred_rf)
# Out:
# 0.2615115022765831

# %%
np.sqrt(mean_squared_error(y_test,y_pred_rf))
# Out:
# 0.5113819534130855

# %%
#create a residual and plot it 
residuals=y_test-y_pred_rf

# %%
sns.displot(residuals, kind='kde',color='yellow')

# %%
residual2=y_test-reg_pred# using the older model
sns.displot(residual2,kind='kde',color='black')

# %% [markdown]
# <h2>Semi conclusion</h2>
# <p>From the analyses we performed so far,  we have we can conclude that:
# <br>We try 2 algorithms ; Linear Regression that gave us 0.59 and Random Forest Regressor that gave 0.80.The second one perform better</br>
# </p>
#
# <p> that analyse is not done yet, we will continue later for deployment</p>

# %%
from sklearn.linear_model import ElasticNet
elastic_net = ElasticNet(alpha=0.1, l1_ratio=0.5)
elastic_net.fit(X_train, y_train)
y_pred_en = elastic_net.predict(X_test)
print('Elastic Net Regression MSE:', mean_squared_error(y_test, y_pred_en))
# Out:
# Elastic Net Regression MSE: 0.6600442089595352

# %%
score=r2_score(y_test,y_pred_en)
print(score)
# Out:
# 0.5018537598765785

# %%
residual3=y_test-y_pred_en# using the older model
sns.displot(residual3,kind='kde',color='red')

# %%
#Elastic Net is not that good for this model ;

# %%
import pickle
pickle.dump(y_pred_rf,open('regmodel.pkl','wb'))
pickled_model=pickle.load(open('regmodel.pkl','rb'))

# %%
sns.regplot(x=y_test, y=y_pred_rf, data=data, scatter_kws={'alpha':0.5, 's':15, 'color':'red'}, line_kws={'color':'black','alpha':0.5,'lw': 2})

# Add labels and title
plt.xlabel("", fontsize=16)  # 
plt.ylabel("", fontsize=16)  # 
plt.title("Relationship between variable---true vs predicted value", fontsize=12)

# Add grid for better readability
plt.grid(True, linestyle='--', alpha=0.8)

# Show the plot
plt.show()

# %% [raw]
# #Final conclusion
# Model has been created using Random Forest Regression with a score of 0.80 (80%) that is pretty good
# overall performance
# precision_score:0.802632960277826
# Mean Absolute error:0.32948220968992264
# <br>-Mean Squarred error:0.261511502276583</br>
# <br>-Root mean squarred error:
# 0.51138195341308</br5
